# %%
#Importing libraries and reading the csv file

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg' 
plt.style.use('fivethirtyeight')

jan31= pd.read_csv(r'D:\Kaggle Datasets\Top 100 Cryptocurrency 2022.csv',index_col='Ranking')
jan31.head()
# Out:
#                 Crypto Name    Price Changes 24H  Changes 7D  Changes 30D   \
# Ranking
# 1                   BITCOIN  $36,983       -2.97%       1.96%      -20.08%
# 2           WRAPPED BITCOIN  $37,019       -2.84%       1.84%      -20.13%
# 3                HUOBI BTC   $36,942       -4.24%       1.37%      -20.39%
# 4                  ETHEREUM   $2,510       -3.64%      -1.28%      -32.04%
# 5        LIDO STAKED ETHER    $2,494       -3.23%      -1.84%      -31.98%
#
#         Changes 1Y Market Cap Volume 24H Available Supply
# Ranking
# 1            8.25%  $701.49 B   $13.01 B      18.94 M BTC
# 2            8.26%   $10.04 B  $253.14 M    271.16 K WBTC
# 3            7.82%    $1.47 B   $29.51 M     39.88 K HBTC
# 4           82.54%  $298.87 B   $10.00 B     119.38 M ETH
# 5           95.88%    $4.48 B    $2.07 M     1.79 M STETH

# %%
jan31.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1 to 100
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Crypto Name       100 non-null    object
#  1   Price             100 non-null    object
#  2   Changes 24H       100 non-null    object
#  3   Changes 7D        100 non-null    object
#  4   Changes 30D       100 non-null    object
#  5   Changes 1Y        100 non-null    object
#  6   Market Cap        100 non-null    object
#  7   Volume 24H        100 non-null    object
#  8   Available Supply  99 non-null     object
# dtypes: object(9)
# memory usage: 7.8+ KB

# %%
jan31['Price_USD']=jan31['Price'].str.strip('$')
del jan31['Price']
jan31.head()
# Out:
#                 Crypto Name Changes 24H  Changes 7D  Changes 30D  Changes 1Y  \
# Ranking
# 1                   BITCOIN       -2.97%       1.96%      -20.08%      8.25%
# 2           WRAPPED BITCOIN       -2.84%       1.84%      -20.13%      8.26%
# 3                HUOBI BTC        -4.24%       1.37%      -20.39%      7.82%
# 4                  ETHEREUM       -3.64%      -1.28%      -32.04%     82.54%
# 5        LIDO STAKED ETHER        -3.23%      -1.84%      -31.98%     95.88%
#
#         Market Cap Volume 24H Available Supply Price_USD
# Ranking
# 1        $701.49 B   $13.01 B      18.94 M BTC    36,983
# 2         $10.04 B  $253.14 M    271.16 K WBTC    37,019
# 3          $1.47 B   $29.51 M     39.88 K HBTC    36,942
# 4        $298.87 B   $10.00 B     119.38 M ETH     2,510
# 5          $4.48 B    $2.07 M     1.79 M STETH     2,494

# %%
jan31['Price_USD']=jan31['Price_USD'].str.replace(',','')
jan31['Price_USD']=jan31['Price_USD'].astype('float')

# %%
print(jan31.columns)
# Out:
# Index(['Crypto Name', 'Changes 24H ', 'Changes 7D ', 'Changes 30D ',
#        'Changes 1Y', 'Market Cap', 'Volume 24H', 'Available Supply',
#        'Price_USD'],
#       dtype='object')

# %%
jan31['changes_24h']=jan31['Changes 24H '].str.replace('%','')
del jan31['Changes 24H ']
jan31.columns
# Out:
# Index(['Crypto Name', 'Changes 7D ', 'Changes 30D ', 'Changes 1Y',
#        'Market Cap', 'Volume 24H', 'Available Supply', 'Price_USD',
#        'changes_24h'],
#       dtype='object')

# %%
jan31['changes_24h']=jan31['changes_24h'].str.replace('$','')
# Out:
# <ipython-input-177-28a579cc3b7b>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   jan31['changes_24h']=jan31['changes_24h'].str.replace('$','')

# %%
jan31['changes_24h']=jan31['changes_24h'].astype('float')

# %%
jan31['changes_7d']=jan31['Changes 7D '].str.replace('%','')
del jan31['Changes 7D ']
jan31.columns
jan31['changes_7d']=jan31['changes_7d'].str.replace('$','')
jan31['changes_7d']=jan31['changes_7d'].astype('float')
# Out:
# <ipython-input-179-5feb7cb634c1>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   jan31['changes_7d']=jan31['changes_7d'].str.replace('$','')

# %%
jan31['changes_30d']=jan31['Changes 30D '].str.replace('%','')
del jan31['Changes 30D ']
jan31.columns
jan31['changes_30d']=jan31['changes_30d'].str.replace('$','')
jan31['changes_30d']=jan31['changes_30d'].astype('float')
# Out:
# <ipython-input-180-072e0211e9a0>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   jan31['changes_30d']=jan31['changes_30d'].str.replace('$','')

# %%
jan31['changes_1y']=jan31['Changes 1Y'].str.replace('%','')
del jan31['Changes 1Y']

# %%
jan31.head()
# Out:
#                 Crypto Name Market Cap Volume 24H Available Supply  Price_USD  \
# Ranking
# 1                   BITCOIN  $701.49 B   $13.01 B      18.94 M BTC    36983.0
# 2           WRAPPED BITCOIN   $10.04 B  $253.14 M    271.16 K WBTC    37019.0
# 3                HUOBI BTC     $1.47 B   $29.51 M     39.88 K HBTC    36942.0
# 4                  ETHEREUM  $298.87 B   $10.00 B     119.38 M ETH     2510.0
# 5        LIDO STAKED ETHER     $4.48 B    $2.07 M     1.79 M STETH     2494.0
#
#          changes_24h  changes_7d  changes_30d changes_1y
# Ranking
# 1              -2.97        1.96       -20.08       8.25
# 2              -2.84        1.84       -20.13       8.26
# 3              -4.24        1.37       -20.39       7.82
# 4              -3.64       -1.28       -32.04      82.54
# 5              -3.23       -1.84       -31.98      95.88

# %%
jan31.loc[22]
# Out:
# Crypto Name                 TERRA
# Market Cap               $17.59 B
# Volume 24H                $1.59 B
# Available Supply    400.68 M LUNA
# Price_USD                   44.13
# changes_24h                 -37.4
# changes_7d                  -48.8
# changes_30d               2959.17
# changes_1y               $17.59 B
# Name: 22, dtype: object

# %%
jan31.drop(index=22)

# %%
jan31['changes_1y']=jan31['changes_1y'].astype('float')

# %%
jan31['market_cap_billion']=jan31['Market Cap'].str.replace('B','')

# %%
del jan31["Market Cap"]

# %%
jan31['market_cap_billion']=jan31['market_cap_billion'].str.strip('$')

# %%
jan31['market_cap_billion']=jan31['market_cap_billion'].str.strip('%')

# %%
jan31['market_cap_billion']=jan31['market_cap_billion'].astype('float')

# %%
jan31.head()
# Out:
#                 Crypto Name Volume 24H Available Supply  Price_USD  \
# Ranking
# 1                   BITCOIN   $13.01 B      18.94 M BTC    36983.0
# 2           WRAPPED BITCOIN  $253.14 M    271.16 K WBTC    37019.0
# 3                HUOBI BTC    $29.51 M     39.88 K HBTC    36942.0
# 4                  ETHEREUM   $10.00 B     119.38 M ETH     2510.0
# 5        LIDO STAKED ETHER     $2.07 M     1.79 M STETH     2494.0
#
#          changes_24h  changes_7d  changes_30d  changes_1y  market_cap_billion
# Ranking
# 1              -2.97        1.96       -20.08        8.25              701.49
# 2              -2.84        1.84       -20.13        8.26               10.04
# 3              -4.24        1.37       -20.39        7.82                1.47
# 4              -3.64       -1.28       -32.04       82.54              298.87
# 5              -3.23       -1.84       -31.98       95.88                4.48

# %%
jan31.sort_values('market_cap_billion',ascending=False)
# Out:
#            Crypto Name Volume 24H Available Supply  Price_USD  changes_24h  \
# Ranking
# 1              BITCOIN   $13.01 B      18.94 M BTC   36983.00        -2.97
# 4             ETHEREUM   $10.00 B     119.38 M ETH    2510.00        -3.64
# 49           LEO TOKEN  $445.62 K     937.38 M LEO       3.59         2.66
# 72              TETHER   $32.57 B     78.12 B USDT       1.00        -0.33
# 7        BINANCE COIN     $1.05 B     168.14 M BNB     369.80        -3.80
# ...                ...        ...              ...        ...          ...
# 45              KADENA   $29.46 M     167.82 M KDA       5.58       -13.21
# 98            SAFEMOON  $410.28 K     566.50 B SFM       0.00        -3.19
# 90                 NEM   $18.66 M       9.00 B XEM       0.10        -5.19
# 40               WAVES   $79.10 M   100.00 M WAVES       8.58       -11.55
# 38         BITKUB COIN    $5.11 M      88.75 M KUB       9.53        -2.15
#
#          changes_7d  changes_30d  changes_1y  market_cap_billion
# Ranking
# 1              1.96       -20.08        8.25           701.49000
# 4             -1.28       -32.04       82.54           298.87000
# 49             0.42        -4.72      156.78           156.78000
# 72             0.18         0.32        0.53            78.26000
# 7             -3.37       -27.62      730.32            62.31000
# ...             ...          ...         ...                 ...
# 45            -3.04       -55.02     2956.40             0.93697
# 98            -3.72       -34.03        0.00             0.93363
# 90             1.07       -19.81      -57.17             0.88930
# 40            -5.24       -40.13       30.83             0.87179
# 38            10.83       -35.09        0.00             0.84704
#
# [99 rows x 9 columns]

# %%
cap= jan31[['Crypto Name','market_cap_billion']].set_index('Crypto Name')

# %%
cap10= cap.sort_values('market_cap_billion',ascending=False)[:10]

# %%
cap10 = cap10.assign(market_cap_perc = lambda x: (x.market_cap_billion / cap.market_cap_billion.sum())*100)

# %%
#Declaring these now for later use in the plots
TOP_CAP_TITLE = 'Top 10 market capitalization'
TOP_CAP_YLABEL = '% of total cap'
# Plotting the barplot with the title defined above 
ax = cap10.market_cap_perc.plot.bar(title=TOP_CAP_TITLE)

# Annotating the y axis with the label defined above
ax.set_ylabel(TOP_CAP_YLABEL);

# %%
# Colors for the bar plot
COLORS = ['orange', 'green', 'orange', 'cyan', 'cyan', 'blue', 'silver', 'orange', 'red', 'green']

# Plotting market_cap_usd as before but adding the colors and scaling the y-axis  
ax = cap10.market_cap_billion.plot.bar(title=TOP_CAP_TITLE, logy=True, color = COLORS)

# Annotating the y axis with log(USD)
ax.set_ylabel('log(Billion USD)')

# Final touch! Removing the xlabel as it is not very informative
ax.set_xlabel('');

# %%
# Selecting the id, percent_change_24h and percent_change_7d columns
volatility = jan31[['Crypto Name','changes_24h','changes_7d']]

# Setting the index to 'id' and dropping all NaN rows
volatility = volatility.set_index('Crypto Name').dropna()

# Sorting the DataFrame by percent_change_24h in ascending order
volatility = volatility.sort_values('changes_24h')

# Checking the first few rows
volatility.head()
# Out:
#                changes_24h  changes_7d
# Crypto Name
# KADENA              -13.21       -3.04
# WAVES               -11.55       -5.24
# THETA NETWORK       -11.17       -1.82
# FANTOM              -10.46      -14.35
# GALA                 -9.79       -6.82

# %%
# Defining a function with 2 parameters, the series to plot and the title
def top10_subplot(volatility_series, title):
    # making the subplot and the figure for nrows and ncolumns
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
    # Plotting with pandas the barchart for the top 10 losers with the color RED
    ax = volatility_series[:10].plot.bar(color="darkred", ax=axes[0])
    # Setting the main title to TITLE
    fig.suptitle(title)
    # Setting the ylabel to "% change"
    ax.set_ylabel('% change')
    # Same as above, but for the top 10 winners and in darkblue
    ax = volatility_series[-10:].plot.bar(color="darkblue", ax=axes[1])
    # Returning this for good practice, might use later
    return fig, ax

DTITLE = "24 hours top losers and winners"

# Calling the function above with the volatility.percent_change_24h series
# and title DTITLE 
fig, ax = top10_subplot(volatility.changes_24h, DTITLE)

# %%
# Sorting in ascending order
volatility7d = volatility['changes_7d'].sort_values()

WTITLE = "Weekly top losers and winners"

# Calling the top10_subplot function
fig, ax = top10_subplot(volatility7d,WTITLE)

# %%
# Selecting everything bigger than 10 billion 
largecaps = cap.query('market_cap_billion>10')

# Printing out largecaps
print(largecaps)
# Out:
#                  market_cap_billion
# Crypto Name
# BITCOIN                      701.49
# WRAPPED BITCOIN               10.04
# ETHEREUM                     298.87
# BINANCE COIN                  62.31
# SOLANA                        28.43
# AVALANCHE                     15.94
# POLKADOT                      18.71
# LEO TOKEN                    156.78
# POLYGON                       10.61
# CARDANO                       32.59
# TERRAUSD                      11.29
# BINANCE USD                   15.02
# USD COIN                      49.96
# TETHER                        78.26
# XRP                           27.95
# CRYPTO.COM COIN               10.24
# DOGECOIN                      18.25
# SHIBA INU                     11.27

# %%
highest_returns=jan31.sort_values('changes_1y',ascending=False)[:10][['Crypto Name','changes_1y']]
print(highest_returns)
# Out:
#            Crypto Name  changes_1y
# Ranking
# 100          SHIBA INU     9999.99
# 96               ECOMI     9999.99
# 84                GALA     6017.42
# 20       AXIE INFINITY     5924.29
# 47         THE SANDBOX     4325.82
# 60             POLYGON     3787.96
# 45              KADENA     2956.40
# 14             SOLANA      2028.16
# 85             HARMONY     1838.46
# 54        DECENTRALAND     1555.99

# %%
lowest_returns=jan31.sort_values('changes_1y',ascending=True)[:10][['Crypto Name','changes_1y']]
print(lowest_returns)
# Out:
#                      Crypto Name  changes_1y
# Ranking
# 46       SYNTHETIX NETWORK TOKEN      -71.09
# 90                           NEM      -57.17
# 11                          AAVE      -54.25
# 55               CELSIUS NETWORK      -46.97
# 36                       UNISWAP      -46.31
# 83                       STELLAR      -40.39
# 80                     THE GRAPH      -39.65
# 8                  BITCOIN CASH       -31.87
# 35                     CHAINLINK      -28.65
# 44                          FLOW      -25.81

# %%
highest_returns.plot.bar(x='Crypto Name',y='changes_1y',xlabel="Crypto",ylabel='Positive Precentage Change',title="Yearly Returns")

plt.show()

# %%
lowest_returns.plot.bar(x='Crypto Name',y='changes_1y',xlabel="Crypto",ylabel='Nagative Precentage Change',title="Yearly Loss")

plt.show()
